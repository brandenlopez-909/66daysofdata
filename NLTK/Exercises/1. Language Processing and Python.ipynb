# %% [markdown]
# **Only doing questions I do not automatically know.

# %% [markdown]
# # 3 The Python multiplication operation can be applied to lists. What happens when you type ['Monty', 'Python'] * 20, or 3 * sent1?

# %%
test = ['Monty', 'Python']
test*20
# Out:
# ['Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python']

# %%
import nltk
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
3 * sent1
# Out:
# ['Call',
#  'me',
#  'Ishmael',
#  '.',
#  'Call',
#  'me',
#  'Ishmael',
#  '.',
#  'Call',
#  'me',
#  'Ishmael',
#  '.']

# %% [markdown]
# # 4. Review 1 on computing with language. How many words are there in text2? How many distinct words are there?

# %%
len(set(w.lower() for w in text2 if w.isalpha()))
# Out:
# 6283

# %% [markdown]
# # 6. Produce a dispersion plot of the four main protagonists in Sense and Sensibility: Elinor, Marianne, Edward, and Willoughby. What can you observe about the different roles played by the males and females in this novel? Can you identify the couples?

# %%
text2.dispersion_plot(['Elinor', 'Marianne', 'Edward', 'Willoughby'])
# Females are the main characters in this book. 
# I cannot confidently id the couples but I am guessing Elinor and Willoughby are a couple 
# Then Marianne and Edward are the other couple?

# %% [markdown]
# # 7. Find the collocations in text5.

# %%
"; ".join(text5.collocation_list())
# Out:
# 'wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART; cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime Player; Player 12%; dont know; lez gurls; long time'

# %% [markdown]
# # 13. We have seen how to represent a sentence as a list of words, where each word is a sequence of characters. What does sent1[2][2] do? Why? Experiment with other index values.

# %%
sent1[2]
# Out:
# 'Ishmael'

# %%
sent1[2][2]
# It gets the second word then second letter of that word.
# Out:
# 'h'

# %% [markdown]
# # 17. Use text9.index() to find the index of the word sunset. You'll need to insert this word as an argument between the parentheses. By a process of trial and error, find the slice for the complete sentence that contains this word.

# %%
text9.index('sunset')
# Out:
# 629

# %% [markdown]
# # 22. Find all the four-letter words in the Chat Corpus (text5). With the help of a frequency distribution (FreqDist), show these words in decreasing order of frequency.

# %%
sorted((w.lower() for w in set(text5) if len(w) ==4 and w.isalpha()))
# Out:
# ['able',
#  'abou',
#  'acid',
#  'adds',
#  'addy',
#  'ages',
#  'ahah',
#  'ahem',
#  'ahhh',
#  'ahhh',
#  'aime',
#  'aint',
#  'akdt',
#  'akon',
#  'akst',
#  'allo',
#  'ally',
#  'alot',
#  'also',
#  'amen',
#  'anal',
#  'anti',
#  'area',
#  'argh',
#  'arms',
#  'army',
#  'asks',
#  'asss',
#  'aunt',
#  'away',
#  'away',
#  'away',
#  'awww',
#  'awww',
#  'babe',
#  'babi',
#  'baby',
#  'back',
#  'back',
#  'bacl',
#  'ball',
#  'band',
#  'bare',
#  'barn',
#  'base',
#  'beam',
#  'bear',
#  'beat',
#  'been',
#  'been',
#  'beer',
#  'bein',
#  'bell',
#  'bend',
#  'benz',
#  'best',
#  'bied',
#  'bike',
#  'bird',
#  'bite',
#  'blah',
#  'blew',
#  'bloe',
#  'blow',
#  'blue',
#  'body',
#  'boed',
#  'bois',
#  'bomb',
#  'bone',
#  'bone',
#  'bong',
#  'book',
#  'boom',
#  'boot',
#  'born',
#  'born',
#  'boss',
#  'both',
#  'bout',
#  'bowl',
#  'boys',
#  'boyz',
#  'brad',
#  'brat',
#  'bred',
#  'brwn',
#  'buff',
#  'bugs',
#  'bull',
# ...

# %%
FreqDist(sorted((w.lower() for w in set(text5) if len(w) ==4 and w.isalpha()), reverse=True ) )
# Out:
# FreqDist({'here': 4, 'your': 3, 'will': 3, 'when': 3, 'time': 3, 'they': 3, 'that': 3, 'talk': 3, 'stop': 3, 'sexy': 3, ...})

# %% [markdown]
# # 24. Write expressions for finding all words in text6 that meet the conditions listed below. The result should be in the form of a list of words: ['word1', 'word2', ...].
#
# Ending in ise
#
# Containing the letter z
#
# Containing the sequence of letters pt
#
# Having all lowercase letters except for an initial capital (i.e., titlecase)

# %%
sorted(w for w in text6 if w.endswith("ise") or "z" in w or "pt" in w or w.istitle and w.isalpha())
# Out:
# ['A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'ALL',
#  'ALL',
#  'ALL',
#  'ALL',
#  'ALL',
#  'AMAZING',
#  'ANIMATOR',
#  'ARMY',
#  'ARMY',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
#  'ARTHUR',
# ...

# %% [markdown]
# # 25. Define sent to be the list of words ['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']. Now write code to perform the following tasks:
#
# Print all words beginning with sh
#
# Print all words longer than four characters

# %%
q25 = ['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']
sorted(w for w in q25 if w.startswith('sh') or len(w) > 4)
# Out:
# ['sells', 'she', 'shells', 'shore']

# %% [markdown]
# # 26. What does the following Python code do? sum(len(w) for w in text1) Can you use it to work out the average word length of a text?

# %%
# Sums the length of every word used in text1
sum(len(w) for w in text1)
# Out:
# 999044

# %%
sum(len(w) for w in text1) / len(list(len(w) for w in text1))
## The average length is 3.8 charaters.
# Out:
# 3.830411128023649

# %% [markdown]
# # 27. Define a function called vocab_size(text) that has a single parameter for the text, and which returns the vocabulary size of the text.

# %%
#Getting Word Types is not my strong suit. 
def vocab_size(text):
    #We don't want a set as we want to keep all words that are alphabetical 
    #Send it to lowercase so A == a.
    return len(list(w.lower() for w in text if w.isalpha()))

# %%
vocab_size(text1)
# Out:
# 218361

# %%
len(text1)
# Out:
# 260819

# %% [markdown]
# # 28. Define a function percent(word, text) that calculates how often a given word occurs in a text, and expresses the result as a percentage.

# %%
def percent(word, text):
    word_type = vocab_size(text)
    return 100*text.count(word)/word_type

# %%
percent("a" ,text4)
# Out:
# 1.609313978336158
